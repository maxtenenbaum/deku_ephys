# %%
import neo

# %%
reader = neo.io.BlackrockIO("/Users/maxtenenbaum/Desktop/Code/Deku Lab Neural Data Analysis/deku_ephys/data/raw/2023_10_26 NNX new settings at baseline001.ns5")

# %%
block = reader.read_block()

# %%
print(block)

# %%
analog_signal = block.segments[0].analogsignals[0]

# %%
print(analog_signal)
# Out:
# [[  90.75  114.75   54.25 ...   67.5   114.25   68.75]
#  [  93.25  108.5    58.25 ...   60.25  118.25   83.75]
#  [  88.75  115.25   58.5  ...   61.    119.5    87.5 ]
#  ...
#  [ -67.75 -100.5   -44.5  ...  -62.   -106.5   -74.25]
#  [ -73.75 -111.25  -36.75 ...  -72.5  -101.75  -79.25]
#  [ -76.75 -108.    -46.   ...  -67.    -94.25  -73.5 ]] uV

# %%
analog_signal.shape
# Out:
# (467935, 16)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(range(len(analog_signal)), analog_signal)
# Out:
# /var/folders/b_/9rg7lxg1137dr6djc60j1lwr0000gn/T/ipykernel_59667/523398986.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
first_channel = analog_signal[0,5]

# %%
first_channel.shape
# Out:
# ()

# %%
new_read = neo.io.BlackrockIO('/Users/maxtenenbaum/Desktop/Code/Deku Lab Neural Data Analysis/deku_ephys/data/raw/2023_10_26 NNX new settings at baseline001.nev')
